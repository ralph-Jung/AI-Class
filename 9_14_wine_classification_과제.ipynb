# %% [markdown]
# <a href="https://colab.research.google.com/github/ralph-Jung/AI-Class/blob/main/9_14_wine_classification_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Decision Tree
# 4가지 모델 다 돌려봤을 때 세토나만 유일하게 항상 분류가 100% 된다

import pandas as pd

from sklearn.model_selection import train_test_split
# 의사결정나무 분류 모델. 데이터를 조건에 따라 가지치기하듯 나눠서 분류하는 알고리즘.
from sklearn.tree import DecisionTreeClassifier
# 예측값이 실제값과 얼마나 맞았는지 정확도(맞춘 비율)를 계산 / 클래스별로 precision(정밀도), recall(재현율), f1-score 등을 표로 정리해서 보여줌
from sklearn.metrics import accuracy_score, classification_report


# 데이터에는 데이터 프레임(액셀 형식이 데이터프레임 이다) 과 넘파이 로 나눈다
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/wine.csv")


# x에는 species 를 제외한 나머지 열들을 가져옴 ( 입력 데이터 )
X = df.drop("Wine", axis=1)
# y에는 품종  ( 정답 데이터 )
y = df["Wine"]


# 전체 데이터를 80% 는 학습용으로 사용하고 나머지 20% 는 테스트 용으로 나누기
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# model 이라는 변수에 내가 원하는 모델을 추가한다
# 의사결정트리
model = DecisionTreeClassifier()

# model 을 학습 데이터를 바탕으로 학습 시킨다
model.fit(X_train, y_train)

# 내가 위에서 테스트 데이터 20% 만들어 놓은 것을 가지고 얼마나 성능이 나오는지 예측
# 여기 y_pred 에는 X_test를 모델에 넣었을 때 나온 y 값들이 나오고 이 예측값을 정답인 y_pred 랑 비교를 해서 몇개를 맞췄는지 정확도를 매긴다
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))

print()

print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8611111111111112
#
#               precision    recall  f1-score   support
#
#            1       0.92      0.79      0.85        14
#            2       0.76      0.93      0.84        14
#            3       1.00      0.88      0.93         8
#
#     accuracy                           0.86        36
#    macro avg       0.89      0.86      0.87        36
# weighted avg       0.88      0.86      0.86        36

# %%
# 2. Random Forest
import pandas as pd

from sklearn.model_selection import train_test_split
# 의사결정나무 분류 모델. 데이터를 조건에 따라 가지치기하듯 나눠서 분류하는 알고리즘.
from sklearn.ensemble import RandomForestClassifier
# 예측값이 실제값과 얼마나 맞았는지 정확도(맞춘 비율)를 계산 / 클래스별로 precision(정밀도), recall(재현율), f1-score 등을 표로 정리해서 보여줌
from sklearn.metrics import accuracy_score, classification_report


# 데이터에는 데이터 프레임(액셀 형식이 데이터프레임 이다) 과 넘파이 로 나눈다
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/wine.csv")


# x에는 species 를 제외한 나머지 열들을 가져옴 ( 입력 데이터 )
X = df.drop("Wine", axis=1)
# y에는 품종  ( 정답 데이터 )
y = df["Wine"]


# 전체 데이터를 80% 는 학습용으로 사용하고 나머지 20% 는 테스트 용으로 나누기
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# model 이라는 변수에 내가 원하는 모델을 추가한다
# 의사결정트리
model = DecisionTreeClassifier()

# model 을 학습 데이터를 바탕으로 학습 시킨다
model.fit(X_train, y_train)

# 내가 위에서 테스트 데이터 20% 만들어 놓은 것을 가지고 얼마나 성능이 나오는지 예측
# 여기 y_pred 에는 X_test를 모델에 넣었을 때 나온 y 값들이 나오고 이 예측값을 정답인 y_pred 랑 비교를 해서 몇개를 맞췄는지 정확도를 매긴다
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))

print()

print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9444444444444444
#
#               precision    recall  f1-score   support
#
#            1       1.00      0.92      0.96        13
#            2       0.94      0.94      0.94        17
#            3       0.86      1.00      0.92         6
#
#     accuracy                           0.94        36
#    macro avg       0.93      0.95      0.94        36
# weighted avg       0.95      0.94      0.94        36

# %%
# 3. Logistic Regression
import pandas as pd

from sklearn.model_selection import train_test_split
# 의사결정나무 분류 모델. 데이터를 조건에 따라 가지치기하듯 나눠서 분류하는 알고리즘.
from sklearn.linear_model import LogisticRegression
# 예측값이 실제값과 얼마나 맞았는지 정확도(맞춘 비율)를 계산 / 클래스별로 precision(정밀도), recall(재현율), f1-score 등을 표로 정리해서 보여줌
from sklearn.metrics import accuracy_score, classification_report


# 데이터에는 데이터 프레임(액셀 형식이 데이터프레임 이다) 과 넘파이 로 나눈다
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/wine.csv")


# x에는 species 를 제외한 나머지 열들을 가져옴 ( 입력 데이터 )
X = df.drop("Wine", axis=1)
# y에는 품종  ( 정답 데이터 )
y = df["Wine"]


# 전체 데이터를 80% 는 학습용으로 사용하고 나머지 20% 는 테스트 용으로 나누기
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# model 이라는 변수에 내가 원하는 모델을 추가한다
# 의사결정트리
model = LogisticRegression(max_iter=200)

# model 을 학습 데이터를 바탕으로 학습 시킨다
model.fit(X_train, y_train)

# 내가 위에서 테스트 데이터 20% 만들어 놓은 것을 가지고 얼마나 성능이 나오는지 예측
# 여기 y_pred 에는 X_test를 모델에 넣었을 때 나온 y 값들이 나오고 이 예측값을 정답인 y_pred 랑 비교를 해서 몇개를 맞췄는지 정확도를 매긴다
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))

print()

print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
#
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        12
#            2       1.00      1.00      1.00        11
#            3       1.00      1.00      1.00        13
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# 4. KNN
import pandas as pd

from sklearn.model_selection import train_test_split
# 의사결정나무 분류 모델. 데이터를 조건에 따라 가지치기하듯 나눠서 분류하는 알고리즘.
from sklearn.neighbors import KNeighborsClassifier
# 예측값이 실제값과 얼마나 맞았는지 정확도(맞춘 비율)를 계산 / 클래스별로 precision(정밀도), recall(재현율), f1-score 등을 표로 정리해서 보여줌
from sklearn.metrics import accuracy_score, classification_report


# 데이터에는 데이터 프레임(액셀 형식이 데이터프레임 이다) 과 넘파이 로 나눈다
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/wine.csv")


# x에는 species 를 제외한 나머지 열들을 가져옴 ( 입력 데이터 )
X = df.drop("Wine", axis=1)
# y에는 품종  ( 정답 데이터 )
y = df["Wine"]


# 전체 데이터를 80% 는 학습용으로 사용하고 나머지 20% 는 테스트 용으로 나누기
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# model 이라는 변수에 내가 원하는 모델을 추가한다
# 의사결정트리
model = KNeighborsClassifier()

# model 을 학습 데이터를 바탕으로 학습 시킨다
model.fit(X_train, y_train)

# 내가 위에서 테스트 데이터 20% 만들어 놓은 것을 가지고 얼마나 성능이 나오는지 예측
# 여기 y_pred 에는 X_test를 모델에 넣었을 때 나온 y 값들이 나오고 이 예측값을 정답인 y_pred 랑 비교를 해서 몇개를 맞췄는지 정확도를 매긴다
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))

print()

print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.6666666666666666
#
#               precision    recall  f1-score   support
#
#            1       0.71      1.00      0.83        10
#            2       0.67      0.71      0.69        14
#            3       0.57      0.33      0.42        12
#
#     accuracy                           0.67        36
#    macro avg       0.65      0.68      0.65        36
# weighted avg       0.65      0.67      0.64        36
