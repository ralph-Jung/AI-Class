# %% [markdown]
# <a href="https://colab.research.google.com/github/ralph-Jung/AI-Class/blob/main/9_14_%EC%8B%A4%EC%8A%B5_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Decision Tree
import pandas as pd

from sklearn.model_selection import train_test_split
# 의사결정나무 분류 모델. 데이터를 조건에 따라 가지치기하듯 나눠서 분류하는 알고리즘.
from sklearn.tree import DecisionTreeClassifier
# 예측값이 실제값과 얼마나 맞았는지 정확도(맞춘 비율)를 계산 / 클래스별로 precision(정밀도), recall(재현율), f1-score 등을 표로 정리해서 보여줌
from sklearn.metrics import accuracy_score, classification_report


# 데이터에는 데이터 프레임(액셀 형식이 데이터프레임 이다) 과 넘파이 로 나눈다
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/iris.csv")


# x에는 species 를 제외한 나머지 열들을 가져옴 ( 입력 데이터 )
X = df.drop("species", axis=1)
# y에는 품종  ( 정답 데이터 )
y = df["species"]


# 전체 데이터를 80% 는 학습용으로 사용하고 나머지 20% 는 테스트 용으로 나누기
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# model 이라는 변수에 내가 원하는 모델을 추가한다
# 의사결정트리
model = DecisionTreeClassifier()

# model 을 학습 데이터를 바탕으로 학습 시킨다
model.fit(X_train, y_train)

# 내가 위에서 테스트 데이터 20% 만들어 놓은 것을 가지고 얼마나 성능이 나오는지 예측
# 여기 y_pred 에는 X_test를 모델에 넣었을 때 나온 y 값들이 나오고 이 예측값을 정답인 y_pred 랑 비교를 해서 몇개를 맞췄는지 정확도를 매긴다
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))

print()

print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9333333333333333
#
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         8
#   versicolor       0.82      1.00      0.90         9
#    virginica       1.00      0.85      0.92        13
#
#     accuracy                           0.93        30
#    macro avg       0.94      0.95      0.94        30
# weighted avg       0.95      0.93      0.93        30

# %%
# 피마 인디언 당뇨병(Pima Indians Diabetes) 데이터셋

import pandas as pd

from sklearn.model_selection import train_test_split
# 의사결정나무 분류 모델. 데이터를 조건에 따라 가지치기하듯 나눠서 분류하는 알고리즘.
from sklearn.tree import DecisionTreeClassifier
# 예측값이 실제값과 얼마나 맞았는지 정확도(맞춘 비율)를 계산 / 클래스별로 precision(정밀도), recall(재현율), f1-score 등을 표로 정리해서 보여줌
from sklearn.metrics import accuracy_score, classification_report

df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/diabetes.csv")

X=df.drop("Outcome",axis=1)

y=df["Outcome"]

# 여기서 학습데이터 랑 테스트데이터를 8:2 로 나눌 때 무작위로 나누기 때문에 실행할 때 마다 정확도가 달라진다
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# model 이라는 변수에 내가 원하는 모델을 추가한다
# 의사결정트리
model = DecisionTreeClassifier()

# model 을 학습 데이터를 바탕으로 학습 시킨다
model.fit(X_train, y_train)

# 내가 위에서 테스트 데이터 20% 만들어 놓은 것을 가지고 얼마나 성능이 나오는지 예측
# 여기 y_pred 에는 X_test를 모델에 넣었을 때 나온 y 값들이 나오고 이 예측값을 정답인 y_pred 랑 비교를 해서 몇개를 맞췄는지 정확도를 매긴다
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))

print()

print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7792207792207793
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.89      0.84       100
#            1       0.74      0.57      0.65        54
#
#     accuracy                           0.78       154
#    macro avg       0.77      0.73      0.74       154
# weighted avg       0.77      0.78      0.77       154
