# %% [markdown]
# <a href="https://colab.research.google.com/github/ralph-Jung/AI-Class/blob/main/9_14_diabete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 피마 인디언 당뇨병(Pima Indians Diabetes) 데이터셋
# 1. Decision Tree
import pandas as pd

from sklearn.model_selection import train_test_split
# 의사결정나무 분류 모델. 데이터를 조건에 따라 가지치기하듯 나눠서 분류하는 알고리즘.
from sklearn.tree import DecisionTreeClassifier
# 예측값이 실제값과 얼마나 맞았는지 정확도(맞춘 비율)를 계산 / 클래스별로 precision(정밀도), recall(재현율), f1-score 등을 표로 정리해서 보여줌
from sklearn.metrics import accuracy_score, classification_report

df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/diabetes.csv")

X=df.drop("Outcome",axis=1)

y=df["Outcome"]

# 여기서 학습데이터 랑 테스트데이터를 8:2 로 나눌 때 무작위로 나누기 때문에 실행할 때 마다 정확도가 달라진다
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# model 이라는 변수에 내가 원하는 모델을 추가한다
# 의사결정트리
model = DecisionTreeClassifier()

# model 을 학습 데이터를 바탕으로 학습 시킨다
model.fit(X_train, y_train)

# 내가 위에서 테스트 데이터 20% 만들어 놓은 것을 가지고 얼마나 성능이 나오는지 예측
# 여기 y_pred 에는 X_test를 모델에 넣었을 때 나온 y 값들이 나오고 이 예측값을 정답인 y_pred 랑 비교를 해서 몇개를 맞췄는지 정확도를 매긴다
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))

print()

print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.6948051948051948
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.74      0.77       108
#            1       0.49      0.59      0.53        46
#
#     accuracy                           0.69       154
#    macro avg       0.65      0.66      0.65       154
# weighted avg       0.71      0.69      0.70       154

# %%
# 2. Random Forest

import pandas as pd

from sklearn.model_selection import train_test_split
# 의사결정나무 분류 모델. 데이터를 조건에 따라 가지치기하듯 나눠서 분류하는 알고리즘.
from sklearn.ensemble import RandomForestClassifier
# 예측값이 실제값과 얼마나 맞았는지 정확도(맞춘 비율)를 계산 / 클래스별로 precision(정밀도), recall(재현율), f1-score 등을 표로 정리해서 보여줌
from sklearn.metrics import accuracy_score, classification_report

df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/diabetes.csv")

X=df.drop("Outcome",axis=1)

y=df["Outcome"]

# 여기서 학습데이터 랑 테스트데이터를 8:2 로 나눌 때 무작위로 나누기 때문에 실행할 때 마다 정확도가 달라진다
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# model 이라는 변수에 내가 원하는 모델을 추가한다
# 의사결정트리
model = RandomForestClassifier()

# model 을 학습 데이터를 바탕으로 학습 시킨다
model.fit(X_train, y_train)

# 내가 위에서 테스트 데이터 20% 만들어 놓은 것을 가지고 얼마나 성능이 나오는지 예측
# 여기 y_pred 에는 X_test를 모델에 넣었을 때 나온 y 값들이 나오고 이 예측값을 정답인 y_pred 랑 비교를 해서 몇개를 맞췄는지 정확도를 매긴다
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))

print()

print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7597402597402597
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.83       100
#            1       0.71      0.54      0.61        54
#
#     accuracy                           0.76       154
#    macro avg       0.74      0.71      0.72       154
# weighted avg       0.75      0.76      0.75       154

# %%
# 3. Logistic Regression

import pandas as pd

from sklearn.model_selection import train_test_split
# 의사결정나무 분류 모델. 데이터를 조건에 따라 가지치기하듯 나눠서 분류하는 알고리즘.
from sklearn.linear_model import LogisticRegression
# 예측값이 실제값과 얼마나 맞았는지 정확도(맞춘 비율)를 계산 / 클래스별로 precision(정밀도), recall(재현율), f1-score 등을 표로 정리해서 보여줌
from sklearn.metrics import accuracy_score, classification_report

df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/diabetes.csv")

X=df.drop("Outcome",axis=1)

y=df["Outcome"]

# 여기서 학습데이터 랑 테스트데이터를 8:2 로 나눌 때 무작위로 나누기 때문에 실행할 때 마다 정확도가 달라진다
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# model 이라는 변수에 내가 원하는 모델을 추가한다
# 의사결정트리
model = LogisticRegression(max_iter=200)

# model 을 학습 데이터를 바탕으로 학습 시킨다
model.fit(X_train, y_train)

# 내가 위에서 테스트 데이터 20% 만들어 놓은 것을 가지고 얼마나 성능이 나오는지 예측
# 여기 y_pred 에는 X_test를 모델에 넣었을 때 나온 y 값들이 나오고 이 예측값을 정답인 y_pred 랑 비교를 해서 몇개를 맞췄는지 정확도를 매긴다
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))

print()

print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8051948051948052
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86       107
#            1       0.70      0.64      0.67        47
#
#     accuracy                           0.81       154
#    macro avg       0.77      0.76      0.76       154
# weighted avg       0.80      0.81      0.80       154

# %%
# 4. KNN

import pandas as pd

from sklearn.model_selection import train_test_split
# 의사결정나무 분류 모델. 데이터를 조건에 따라 가지치기하듯 나눠서 분류하는 알고리즘.
from sklearn.neighbors import KNeighborsClassifier
# 예측값이 실제값과 얼마나 맞았는지 정확도(맞춘 비율)를 계산 / 클래스별로 precision(정밀도), recall(재현율), f1-score 등을 표로 정리해서 보여줌
from sklearn.metrics import accuracy_score, classification_report

df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/diabetes.csv")

X=df.drop("Outcome",axis=1)

y=df["Outcome"]

# 여기서 학습데이터 랑 테스트데이터를 8:2 로 나눌 때 무작위로 나누기 때문에 실행할 때 마다 정확도가 달라진다
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# model 이라는 변수에 내가 원하는 모델을 추가한다
# 의사결정트리
model = KNeighborsClassifier()

# model 을 학습 데이터를 바탕으로 학습 시킨다
model.fit(X_train, y_train)

# 내가 위에서 테스트 데이터 20% 만들어 놓은 것을 가지고 얼마나 성능이 나오는지 예측
# 여기 y_pred 에는 X_test를 모델에 넣었을 때 나온 y 값들이 나오고 이 예측값을 정답인 y_pred 랑 비교를 해서 몇개를 맞췄는지 정확도를 매긴다
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))

print()

print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7207792207792207
#
#               precision    recall  f1-score   support
#
#            0       0.74      0.85      0.79        96
#            1       0.67      0.50      0.57        58
#
#     accuracy                           0.72       154
#    macro avg       0.71      0.68      0.68       154
# weighted avg       0.71      0.72      0.71       154
